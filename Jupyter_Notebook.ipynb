# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # MYFIRSTNOTEBOOK

# %% [markdown]
# ## this is my first jupyter notebook about data science tools

# %% [markdown]
# ## list of Data science languages:
# *   Python
# *   R
# *   SQL
# *   Julia
# *   Scala
# *   Java
# *   MATLAB

# %% [markdown]
# ## list of Data science libraries:
# *   **Python Libraries:**
#     *   Pandas (for data manipulation and analysis)
#     *   NumPy (for numerical operations)
#     *   Scikit-learn (for machine learning)
#     *   Matplotlib (for plotting and visualization)
#     *   Seaborn (for statistical data visualization)
#     *   TensorFlow (for deep learning)
#     *   Keras (high-level API for neural networks)
#     *   PyTorch (another open-source ML library)
#     **R Libraries:**
#     *   dplyr (for data manipulation)
#     *   ggplot2 (for data visualization)
#     *   caret (for machine learning models)
#     *   Tidyverse (collection of packages)

# %% [markdown]
# ### Data Science Tools
#
# | Category            | Tool Name                     | Description                                          |
# | :------------------ | :---------------------------- | :--------------------------------------------------- |
# | **Data Management** | MySQL, PostgreSQL, MongoDB    | Databases for storing and managing data              |
# | **Data Integration**| Apache AirFlow, Talend        | Tools for data pipeline orchestration and ETL        |
# | **Data Visualization**| Tableau, Power BI, D3.js      | Tools for creating interactive dashboards and reports|
# | **Machine Learning**| Apache Spark, H2O.ai, KNIME   | Platforms for large-scale ML and statistical modeling|
# | **Cloud Platforms** | AWS (SageMaker), Azure (ML Studio), GCP (AI Platform) | Cloud-based ML development and deployment services |
# | **Development Env.**| Jupyter Notebook, RStudio, VS Code | IDEs and environments for coding and analysis        |
# | **Version Control** | Git, GitHub                   | For tracking changes in code and collaboration       |

# %% [markdown]
# ### Arithmetic Expression Examples

# %%
#sample expression
(2+3)*5
# Out:
# 25

# %%
### minutes to hours conversion
min=200
hr=min/60
hr
# Out:
# 3.3333333333333335

# %% [markdown]
# In this notebook, we have accomplished the following:
#
# *   Introduced the purpose of the notebook.
# *   Listed popular data science languages.
# *   Enumerated key data science libraries.
# *   Presented a table of various data science tools.
# *   Demonstrated basic arithmetic operations in code cells.
# *   Provided an example of unit conversion using code.
# *   Practiced creating different types of markdown cells.

# %% [markdown]
# # Author:
# # Anuroop Kumar Kalidas
